# %%
import csv

new = "/data/shared/alzgene26/PathwaysLA/binn_cutted.csv"
old = "/data/shared/alzgene26/PathwaysLA/binn_connectivity.csv"

with open(new,"r", encoding="utf-8") as f:
    data_new = list(csv.reader(f))
    
with open(old,"r", encoding="utf-8") as g:
    data_old = list(csv.reader(g))

# %%
print(len(data_new))
print(len(data_old))
# Out:
# 132816
# 162498
