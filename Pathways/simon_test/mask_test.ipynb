# %%
for i in range(3):
    a = "123" +str(i)
    print(a)
# Out:
# 1230
# 1231
# 1232

# %%
nullfile = '/data/shared/alzgene26/PathwaysLA/MaskMatrixLayers/'

genepool = "OPCs"

layers = []

for i in range(5):
    layers.append(nullfile + genepool + "_layer_"+str(i)+"_mask.csv" )
