# %%
import pandas as pd


# First mask matrix file
df1 = pd.read_csv('~/PathwayData/MaskMatrixLayers/mg_200_mc_200_mhvg1000/oligo_exc3_exc2_vasc_immune_astro_inhi_opcs_exc1_layer_0_mask.csv',index_col=0)
#print(df.shape)


row_labels1 = df1.index # This is the genes
column_labels1 = df1.columns # This is the pathways
matrix1=df1.to_numpy() # This is the mask matrix

print(row_labels1[:])
print(column_labels1)
print(df1.shape,'matrix1')

# Second mask matrix file
df2 = pd.read_csv('~/PathwayData/MaskMatrixLayers/mg_200_mc_200_mhvg1000/oligo_exc3_exc2_vasc_immune_astro_inhi_opcs_exc1_layer_1_mask.csv',index_col=0)

row_labels2 = df2.index # This is the genes
column_labels2 = df2.columns # This is the pathways
matrix2=df2.to_numpy() # This is the mask matrix

print(row_labels2[:])
print(column_labels2)
print(df2.shape,'matrix2')

# Third mask matrix file
df3 = pd.read_csv('~/PathwayData/MaskMatrixLayers/mg_200_mc_200_mhvg1000/oligo_exc3_exc2_vasc_immune_astro_inhi_opcs_exc1_layer_2_mask.csv',index_col=0)

row_labels3 = df3.index # This is pathways
column_labels3 = df3.columns # This is pathways
matrix3=df3.to_numpy() # This is the mask matrix

print(row_labels3[:])
print(column_labels3)
print(df3.shape,'matrix3')

# Fourth mask matrix file
df4 = pd.read_csv('~/PathwayData/MaskMatrixLayers/mg_200_mc_200_mhvg1000/oligo_exc3_exc2_vasc_immune_astro_inhi_opcs_exc1_layer_3_mask.csv',index_col=0)

row_labels4 = df4.index # This is pathways
column_labels4 = df4.columns # This is pathways
matrix4=df4.to_numpy() # This is the mask matrix

print(row_labels4[:])
print(column_labels4)
print(df4.shape,'matrix4')


# Fifth mask matrix file
df5 = pd.read_csv('~/PathwayData/MaskMatrixLayers/mg_200_mc_200_mhvg1000/oligo_exc3_exc2_vasc_immune_astro_inhi_opcs_exc1_layer_4_mask.csv',index_col=0)

row_labels5 = df5.index # This is pathways
column_labels5 = df5.columns # This is pathways
matrix5=df5.to_numpy() # This is the mask matrix

print(row_labels5[:])
print(column_labels5)
print(df5.shape,'matrix5')
# Out:
# Index(['A1BG', 'A2M', 'A4GALT', 'AAAS', 'AACS', 'AADAT', 'AAK1', 'AAMP',
#        'AANAT', 'AARS2',
#        ...
#        'ZNRF2', 'ZNRF3', 'ZP1', 'ZP3', 'ZRANB1', 'ZRSR2', 'ZSWIM8', 'ZW10',
#        'ZWILCH', 'ZWINT'],
#       dtype='object', length=8075)
# Index(['R-HSA-110312', 'R-HSA-110314', 'R-HSA-110320', 'R-HSA-110357',
#        'R-HSA-110373', 'R-HSA-110381', 'R-HSA-111367', 'R-HSA-111452',
#        'R-HSA-111453', 'R-HSA-111465',
#        ...
#        'R-HSA-9954714', 'R-HSA-9954716', 'R-HSA-9955542', 'R-HSA-9955693',
#        'R-HSA-9956508', 'R-HSA-9956520', 'R-HSA-9956529', 'R-HSA-9958517',
#        'R-HSA-9960519', 'R-HSA-9960525'],
#       dtype='object', length=1160)
# (8075, 1160) matrix1
#        'R-HSA-5357801', 'R-HSA-5653656', 'R-HSA-69306', 'R-HSA-73894',
#        'R-HSA-74160', 'R-HSA-8953854', 'R-HSA-8953897', 'R-HSA-8963743',
#        'R-HSA-9609507', 'R-HSA-9612973', 'R-HSA-9709957', 'R-HSA-9748784',
#        'R-HSA-9909396'],
#       dtype='object')
# (188, 29) matrix4
# Index(['R-HSA-109582', 'R-HSA-112316', 'R-HSA-1266738', 'R-HSA-1430728',
#        'R-HSA-1474165', 'R-HSA-1474244', 'R-HSA-1500931', 'R-HSA-162582',
#        'R-HSA-1640170', 'R-HSA-1643685', 'R-HSA-168256', 'R-HSA-1852241',
#        'R-HSA-382551', 'R-HSA-392499', 'R-HSA-397014', 'R-HSA-4839726',
#        'R-HSA-5357801', 'R-HSA-5653656', 'R-HSA-69306', 'R-HSA-73894',
#        'R-HSA-74160', 'R-HSA-8953854', 'R-HSA-8953897', 'R-HSA-8963743',
#        'R-HSA-9609507', 'R-HSA-9612973', 'R-HSA-9709957', 'R-HSA-9748784',
#        'R-HSA-9909396'],
#       dtype='object')
# Index(['output_node'], dtype='object')
# (29, 1) matrix5

# %%
import importlib
import sys

# Remove cached modules completely
for mod in list(sys.modules.keys()):
    if 'custom_train_test_split' in mod or 'train_loader' in mod:
        del sys.modules[mod]

# Now import fresh
import custom_train_test_split
import train_loader
from train_loader import read_adata, xy_datasplit

# Confirm which files are actually being used
print("custom_train_test_split:", custom_train_test_split.__file__)
print("train_loader:", train_loader.__file__)

mask_list = [matrix1, matrix2, matrix3, matrix4, matrix5]
in_features = matrix1.shape[0]
layer_list = [matrix1.shape[1], matrix2.shape[1], matrix3.shape[1], matrix4.shape[1], matrix5.shape[1]]

print(in_features)
print(layer_list)

indices = [0]
print(indices)
filepath = '/data/shared/alzgene26/data/processed_data/completed/mg_200_mc_200_mhvg1000'
train_adata, test_adata, acollection = read_adata(indices=indices, filepath=filepath, train_size=0.8)

print(train_adata)
# Out:
# custom_train_test_split: /data/users/tongv/kand/BBTX11-VT26-07/BINN/custom_train_test_split.py
# train_loader: /data/users/tongv/kand/BBTX11-VT26-07/BINN/train_loader.py
# 8075
# [1160, 551, 188, 29, 1]
# [0]
# Labels to include: ['astro']
# Reading astro
# Creating encoded collection
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AD_status'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 28
#      26 print(indices)
#      27 filepath = '/data/shared/alzgene26/data/processed_data/completed/mg_200_mc_200_mhvg1000'
# ---> 28 train_adata, test_adata, acollection = read_adata(indices=indices, filepath=filepath, train_size=0.8)
#      30 print(train_adata)
#
# File ~/kand/BBTX11-VT26-07/BINN/train_loader.py:16, in read_adata(indices, filepath, train_size)
#      14 def read_adata(indices: list, filepath: str, train_size=0.8):
#      15     #train_adata, test_adata, collection = custom_train_test_split_modified.pipeline(indices, train_size)
# ---> 16     train_adata, test_adata, collection = custom_train_test_split.pipeline(indices, filepath, train_size)
#      17     return train_adata, test_adata, collection
#
# File ~/kand/BBTX11-VT26-07/BINN/custom_train_test_split.py:116, in pipeline(to_include, filepath, train_size)
#     113 datasets = read_files(to_include, filepath)
#     115 print('Creating encoded collection')
# --> 116 collection = create_encoded_collection(datasets)
#     118 print('Do train-test split')
#     119 train_adata, test_adata = custom_train_test_split(collection, train_size)
#
# File ~/kand/BBTX11-VT26-07/BINN/custom_train_test_split.py:82, in create_encoded_collection(datasets)
#      80 cell_type_low_res_encoder.fit(collection.obs["cell_type_low_res"].to_numpy()[:,None])
#      81 cell_type_high_res_encoder.fit(collection.obs["cell_type_high_res"].to_numpy()[:,None])
# ---> 82 status_encoder.fit(collection.obs["AD_status"])
#      84 return collection
#
# File ~/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'AD_status'

# %%
import train_loader 
from train_loader import read_adata
from train_loader import xy_datasplit

mask_list=[matrix1,matrix2,matrix3,matrix4,matrix5]

in_features=matrix1.shape[0]
layer_list=[matrix1.shape[1],matrix2.shape[1],matrix3.shape[1],matrix4.shape[1],matrix5.shape[1]]

print(in_features)
print(layer_list)

indices = [0]
print(indices)
filepath = '/data/shared/alzgene26/data/processed_data/completed/mg_200_mc_200_mhvg1000'
train_adata, test_adata, acollection = read_adata(indices=indices, filepath=filepath, train_size=0.8)



print(train_adata)





#X_train, y_train, X_test, y_test = xy_datasplit(train_adata,test_adata)    
# X will be the gene expression data
# y will be the AD status data


#print(X_train.shape)




#tl.train_loader(X_train,X_test,y_train,y_test,in_features,layer_list,mask_list,training_epochs=5)
# Out:
# 8075
# [1160, 551, 188, 29, 1]
# [0]
# Labels to include: ['astro']
# Reading astro
# Creating encoded collection
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AD_status'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 16
#      14 print(indices)
#      15 filepath = '/data/shared/alzgene26/data/processed_data/completed/mg_200_mc_200_mhvg1000'
# ---> 16 train_adata, test_adata, acollection = read_adata(indices=indices, filepath=filepath, train_size=0.8)
#      20 print(train_adata)
#      26 #X_train, y_train, X_test, y_test = xy_datasplit(train_adata,test_adata)
#      27 # X will be the gene expression data
#      28 # y will be the AD status data
#    (...)     35
#      36 #tl.train_loader(X_train,X_test,y_train,y_test,in_features,layer_list,mask_list,training_epochs=5)
#
# File ~/kand/BBTX11-VT26-07/BINN/train_loader.py:16, in read_adata(indices, filepath, train_size)
#      14 def read_adata(indices: list, filepath: str, train_size=0.8):
#      15     #train_adata, test_adata, collection = custom_train_test_split_modified.pipeline(indices, train_size)
# ---> 16     train_adata, test_adata, collection = custom_train_test_split.pipeline(indices, filepath, train_size)
#      17     return train_adata, test_adata, collection
#
# File ~/kand/BBTX11-VT26-07/BINN/custom_train_test_split.py:116, in pipeline(to_include, filepath, train_size)
#     113 datasets = read_files(to_include, filepath)
#     115 print('Creating encoded collection')
# --> 116 collection = create_encoded_collection(datasets)
#     118 print('Do train-test split')
#     119 train_adata, test_adata = custom_train_test_split(collection, train_size)
#
# File ~/kand/BBTX11-VT26-07/BINN/custom_train_test_split.py:82, in create_encoded_collection(datasets)
#      80 cell_type_low_res_encoder.fit(collection.obs["cell_type_low_res"].to_numpy()[:,None])
#      81 cell_type_high_res_encoder.fit(collection.obs["cell_type_high_res"].to_numpy()[:,None])
# ---> 82 status_encoder.fit(collection.obs["AD_status"])
#      84 return collection
#
# File ~/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'AD_status'
